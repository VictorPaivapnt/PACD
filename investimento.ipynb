# %%
import pandas as pd

# %%
investimento = pd.read_csv('investimento.csv', sep=',', on_bad_lines='skip')

# %%
investimento.head()
# Out:
#                                          nomeProduto nomeRegiao nomeUF  \
# 0                                         "PASTAGEM"   NORDESTE     RN
# 1                             "BALANÇA PARA ANIMAIS"        SUL     RS
# 2                                   "CANA-DE-AÇUCAR"   NORDESTE     MA
# 3  "CONSTRUÇÃO/RECUPERAÇÃO BARRAGEM/TANQUE, SISTE...   NORDESTE     PI
# 4                "DEPÓSITO E INSTALAÇÕES CONGÊNERES"        SUL     SC
#
#    MesEmissao  AnoEmissao  cdPrograma  cdSubPrograma  cdFonteRecurso  \
# 0          11        2021           1              2             300
# 1           6        2025          50              0             403
# 2           8        2017         999              0             502
# 3           7        2019           1              2             502
# 4           3        2013          50              0             505
#
#    cdTipoSeguro  QtdInvest    VlInvest  Atividade  cdModalidade
# ...

# %%
investimento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 795825 entries, 0 to 795824
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   nomeProduto     795825 non-null  object
#  1   nomeRegiao      795825 non-null  object
#  2   nomeUF          795825 non-null  object
#  3   MesEmissao      795825 non-null  int64
#  4   AnoEmissao      795825 non-null  int64
#  5   cdPrograma      795825 non-null  int64
#  6   cdSubPrograma   795825 non-null  int64
#  7   cdFonteRecurso  795825 non-null  int64
#  8   cdTipoSeguro    795825 non-null  int64
#  9   QtdInvest       795825 non-null  int64
#  10  VlInvest        795825 non-null  object
#  11  Atividade       795825 non-null  int64
#  12  cdModalidade    795825 non-null  int64
# dtypes: int64(9), object(4)
# memory usage: 78.9+ MB
